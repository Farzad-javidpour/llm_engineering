# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate


# ----------------------------
# Prompt
# ----------------------------

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a helpful AI teacher."
    ),
    (
        "human",
        "Explain {topic} in simple terms."
    )
])


# ----------------------------
# Model
# ----------------------------

model = init_chat_model(
    "qwen3:1.7b",
    model_provider="ollama",
    temperature=0
)


# ----------------------------
# Runnable Chain
# ----------------------------

chain = prompt | model


# ----------------------------
# Execute
# ----------------------------

response = chain.invoke({
    "topic": "Runnable LangChain"
})


print(response.content)
# Out:
# Runnable LangChain is like a **toolbox** for developers who want to build apps using large language models (like GPT). Think of it as a way to **customize how a language model works** to solve specific tasks. Here's how it works:
#
# ### 1. **The Model**
#    - This is the "brain" of the system. It's the language model (e.g., GPT) that generates text, answers questions, or does tasks.
#    - Think of it as the chef in a restaurant—your model is the chef who prepares food.
#
# ### 2. **The Chain**
#    - This is the **recipe** or **workflow** the model follows to produce an output.
#    - For example, if you want to build a chatbot that answers questions, the chain might include:
#      - **Gather info** (user's question).
#      - **Process info** (analyze the question).
#      - **Generate answer** (write the response).
#    - The chain is like the recipe that tells the model exactly what to do.
#
# ### 3. **Components**
#    - These are the tools the model uses to build its workflow.
#    - Examples:
#      - **Input handler**: Reads user input.
#      - **Output generator**: Writes the final answer.
#      - **Custom logic**: Adds special rules (e.g., "Only answer if the question is about cats").
#
# ### 4. **How It Works**
#    - Developers use **Runnable LangChain** to create **custom workflows**.
#    - For example, you could build a tool that:
#      - Takes a user's question.
#      - Uses the model to answer it.
#      - Displays the answer.
#
# ### 5. **Why It's Useful**
#    - **Flexibility**: You can tweak the chain to suit your needs (e.g., make the model only answer questions about cats).
#    - **Reusability**: Once you build a chain, you can use it in multiple projects.
#    - **Integration**: Works with other tools and APIs (like databases or other models).
#
# ### Example:
# Imagine you want to build a chatbot that answers questions about cats.
# - **Model**: GPT (the "chef").
# - **Chain**:
#   1. User says, "What do cats eat?"
#   2. Model processes the question.
#   3. Model generates the answer: "Cats eat fish, milk, and sometimes human food."
# - **Components**: Input handler, output generator, and a custom rule to only answer about cats.
#
# ### Summary:
# Runnable LangChain is like a **custom recipe** for using a language model. It lets you build apps that can do specific tasks by defining how the model should "cook" (process and generate) its answers. It's all about making the model do what you want, one step at a time. 🐾
