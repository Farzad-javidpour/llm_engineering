# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langchain.agents import create_agent

# خواندن متغیرهای .env
load_dotenv()
model_name = os.getenv("OLLAMA_MODEL")
if not model_name:
    raise ValueError("OLLAMA_MODEL در فایل .env تعریف نشده است.")

# -------------------------
# 1. Tools
# -------------------------

@tool
def add(a: int, b: int) -> int:
    """دو عدد را با هم جمع می‌کند."""
    return a + b


@tool
def multiply(a: int, b: int) -> int:
    """دو عدد را در هم ضرب می‌کند."""
    return a * b


# -------------------------
# 2. Model
# -------------------------

model = init_chat_model(
    model=model_name,
    model_provider="ollama",
    temperature=0
)


# -------------------------
# 3. Agent
# -------------------------

agent = create_agent(
    model=model,
    tools=[add, multiply]
)


# -------------------------
# 4. اجرا
# -------------------------

result = agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": "عدد 20 را در 2 ضرب کن و نتیجه را با عدد 5 جمع کن"
        }
    ]
})


# -------------------------
# 5. نتیجه
# -------------------------

for message in result["messages"]:
    print("=" * 50)
    print(type(message).__name__)
    print(message.content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 54
#      50 # -------------------------
#      51 # 4. اجرا
#      52 # -------------------------
#      53
# ---> 54 result = agent.invoke({
#      55     "messages": [
#      56         {
#      57             "role": "user",
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langgraph\pregel\main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:707, in RunnableSeq.invoke(self, input, config, **kwargs)
#     705     # run in context
#     706     with set_config_context(config, run) as context:
# --> 707         input = context.run(step.invoke, input, config, **kwargs)
#     708 else:
#     709     input = step.invoke(input, config)
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:447, in RunnableCallable.invoke(self, input, config, **kwargs)
#     445         run_manager.on_chain_end(ret)
#     446 else:
# --> 447     ret = self.func(*args, **kwargs)
#     448 if self.recurse and isinstance(ret, Runnable):
#     449     return ret.invoke(input, config)
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain\agents\factory.py:1483, in create_agent.<locals>.model_node(state, runtime)
#    1481 has_structured_output = initial_response_format is not None
#    1482 if wrap_model_call_handler is None:
# -> 1483     model_response = _execute_model_sync(request)
#    1484     return _build_commands(model_response, has_structured_output=has_structured_output)
#    1486 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain\agents\factory.py:1454, in create_agent.<locals>._execute_model_sync(request)
#    1451 if request.system_message:
#    1452     messages = [request.system_message, *messages]
# -> 1454 output = model_.invoke(messages)
#    1455 if name:
#    1456     output.name = name
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_core\runnables\base.py:6014, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    6007 @override
#    6008 def invoke(
#    6009     self,
#    (...)   6012     **kwargs: Any | None,
#    6013 ) -> Output:
# -> 6014     return self.bound.invoke(
#    6015         input,
#    6016         self._merge_configs(config),
#    6017         **{**self.kwargs, **kwargs},
#    6018     )
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
#     491                 callbacks=config.get("callbacks"),
#     492                 tags=config.get("tags"),
#     493                 metadata=config.get("metadata"),
#     494                 run_name=config.get("run_name"),
#     495                 run_id=config.pop("run_id", None),
#     496                 **kwargs,
#     497             ).generations[0][0],
#     498         ).message,
#     499     )
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1877, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1868 @override
#    1869 def generate_prompt(
#    1870     self,
#    (...)   1874     **kwargs: Any,
#    1875 ) -> LLMResult:
#    1876     prompt_messages = [p.to_messages() for p in prompts]
# -> 1877     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1684, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1681 for i, m in enumerate(input_messages):
#    1682     try:
#    1683         results.append(
# -> 1684             self._generate_with_cache(
#    1685                 m,
#    1686                 stop=stop,
#    1687                 run_manager=run_managers[i] if run_managers else None,
#    1688                 **kwargs,
#    1689             )
#    1690         )
#    1691     except BaseException as e:
#    1692         if run_managers:
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2020     result = generate_from_stream(iter(chunks))
#    2021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2022     result = self._generate(
#    2023         messages, stop=stop, run_manager=run_manager, **kwargs
#    2024     )
#    2025 else:
#    2026     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1200, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1193 def _generate(
#    1194     self,
#    1195     messages: list[BaseMessage],
#    (...)   1198     **kwargs: Any,
#    1199 ) -> ChatResult:
# -> 1200     final_chunk = self._chat_stream_with_aggregation(
#    1201         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1202     )
#    1203     generation_info = final_chunk.generation_info
#    1204     chat_generation = ChatGeneration(
#    1205         message=AIMessage(
#    1206             content=final_chunk.text,
#    (...)   1213         generation_info=generation_info,
#    1214     )
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1135, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#    1126 def _chat_stream_with_aggregation(
#    1127     self,
#    1128     messages: list[BaseMessage],
#    (...)   1132     **kwargs: Any,
#    1133 ) -> ChatGenerationChunk:
#    1134     final_chunk = None
# -> 1135     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#    1136         if final_chunk is None:
#    1137             final_chunk = chunk
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1224, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1217 def _iterate_over_stream(
#    1218     self,
#    1219     messages: list[BaseMessage],
#    1220     stop: list[str] | None = None,
#    1221     **kwargs: Any,
#    1222 ) -> Iterator[ChatGenerationChunk]:
#    1223     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1224     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1225         if not isinstance(stream_resp, str):
#    1226             content = (
#    1227                 stream_resp["message"]["content"]
#    1228                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1229                 else ""
#    1230             )
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1122, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#    1119 chat_params = self._chat_params(messages, stop, **kwargs)
#    1121 if chat_params["stream"]:
# -> 1122     yield from self._client.chat(**chat_params)
#    1123 else:
#    1124     yield self._client.chat(**chat_params)
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\ollama\_client.py:191, in Client._request.<locals>.inner()
#     188   e.response.read()
#     189   raise ResponseError(e.response.text, e.response.status_code) from None
# --> 191 for line in r.iter_lines():
#     192   part = json.loads(line)
#     193   if err := part.get('error'):
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:929, in Response.iter_lines(self)
#     927 decoder = LineDecoder()
#     928 with request_context(request=self._request):
# --> 929     for text in self.iter_text():
#     930         for line in decoder.decode(text):
#     931             yield line
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File d:\Projects\llm_engineering\llm_engineering\.venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
