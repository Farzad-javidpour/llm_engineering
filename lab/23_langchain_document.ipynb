# %%
from langchain_core.documents import Document


product = Document(
    page_content="""
    لپ‌تاپ مدل X دارای پردازنده Core i7،
    حافظه 16GB و SSD با ظرفیت 512GB است.
    """,
    
    metadata={
        "product_id": 125,
        "category": "laptop",
        "brand": "Example",
        "price": 1200,
    }
)


print("CONTENT:")
print(product.page_content)

print("\nMETADATA:")
print(product.metadata)
# Out:
# CONTENT:
#
#     لپ‌تاپ مدل X دارای پردازنده Core i7،
#     حافظه 16GB و SSD با ظرفیت 512GB است.
#
#
# METADATA:
# {'product_id': 125, 'category': 'laptop', 'brand': 'Example', 'price': 1200}
