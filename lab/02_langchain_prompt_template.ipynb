# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.chat_models import init_chat_model

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a helpful Python teacher. answer very short"
    ),
    (
        "human",
        "Explain {topic} simply."
    )
])

model = init_chat_model(
    "qwen3:1.7b",
    model_provider="ollama",
    temperature=0
)

chain = prompt | model

response = chain.invoke({
    "topic": "RAG"
})

print(response.content)
# Out:
# RAG (Retrieval-Augmented Generation) is a technique where a model retrieves information from external sources (like documents or databases) and uses that info to generate more accurate and up-to-date answers. It helps models stay informed and improve their responses over time.
