# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import (
    SystemMessage,
    HumanMessage,
)

model = init_chat_model(
    "qwen3:1.7b",
    model_provider="ollama",
    temperature=0,
)

messages = [
    SystemMessage(
        "You are a helpful AI teacher. answer very short"
    ),
    HumanMessage(
        "What is LangChain?"
    ),
]

response = model.invoke(messages)

print(type(response))
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# LangChain is a framework for integrating large language models into applications, providing tools to build conversational agents, generate text, and handle tasks like dialogue and data processing. It simplifies the process of deploying models into real-world scenarios.
