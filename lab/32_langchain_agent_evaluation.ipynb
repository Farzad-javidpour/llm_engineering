# %% [markdown]
# آیا جواب درست بود؟
# آیا Tool درست را انتخاب کرد؟
# آیا پارامتر Tool درست بود؟
# آیا بی‌دلیل Tool را صدا زد؟
# آیا Authorization را رعایت کرد؟
# آیا Guardrail درست عمل کرد؟
# آیا تعداد مراحل بیش از حد شد؟

# %% [markdown]
#                     Agent Evaluation
#                            │
#         ┌──────────────────┼──────────────────┐
#         ▼                  ▼                  ▼
#    Correctness         Reliability          Safety
#         │                  │                  │
#     Answer            Error Rate         Guardrails
#     Tool               Timeout            Auth
#     Arguments          Retries            Data Leak
