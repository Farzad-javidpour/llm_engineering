# %%
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langchain.agents import create_agent


# -------------------------
# 1. Tools
# -------------------------

@tool
def add(a: int, b: int) -> int:
    """دو عدد را با هم جمع می‌کند."""
    return a + b


@tool
def multiply(a: int, b: int) -> int:
    """دو عدد را در هم ضرب می‌کند."""
    return a * b


# -------------------------
# 2. Model
# -------------------------

model = init_chat_model(
    "qwen3:1.7b",
    model_provider="ollama",
    temperature=0
)


# -------------------------
# 3. Agent
# -------------------------

agent = create_agent(
    model=model,
    tools=[add, multiply]
)÷


# -------------------------
# 4. اجرا
# -------------------------

result = agent.invoke({
    "messages": [
        {
            "role": "user",
            "content": "عدد 20 را در 2 ضرب کن و نتیجه را با عدد 5 جمع کن"
        }
    ]
})


# -------------------------
# 5. نتیجه
# -------------------------

for message in result["messages"]:
    print("=" * 50)
    print(type(message).__name__)
    print(message.content)
# Out:
# ==================================================
# HumanMessage
# عدد 20 را در 2 ضرب کن و نتیجه را با عدد 5 جمع کن
# ==================================================
# AIMessage
#
# ==================================================
# ToolMessage
# 40
# ==================================================
# ToolMessage
# 45
# ==================================================
# AIMessage
# The result of multiplying 20 by 2 is 40. Adding 5 to 40 gives **45**.
#
# Final answer:
# **45**
